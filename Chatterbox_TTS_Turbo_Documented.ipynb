# %%
# %%capture
# %%bash
set -e

cd /content

# Download micromamba into /content/bin/micromamba
curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba

# Create a clean env (isolated from Colab’s global packages)
./bin/micromamba create -y -n cb311 -c conda-forge python=3.11 pip

echo "✅ micromamba ready at /content/bin/micromamba"
echo "✅ env created: cb311"

# %%
# %%capture
# %%bash
set -euo pipefail

cd /content
MICROMAMBA="/content/bin/micromamba"

ts() { date +"[%Y-%m-%d %H:%M:%S]"; }

echo "$(ts) Sanity check micromamba:"
ls -lah "$MICROMAMBA"

echo "$(ts) Upgrading pip tooling inside cb311..."
"$MICROMAMBA" run -n cb311 python -m pip install -U pip setuptools wheel --progress-bar on

echo "$(ts) Installing PyTorch 2.5.1 (CUDA 12.1)... (this can take a while)"
"$MICROMAMBA" run -n cb311 pip install \
  --progress-bar on \
  torch==2.5.1+cu121 torchaudio==2.5.1+cu121 torchvision==0.20.1+cu121 \
  --index-url https://download.pytorch.org/whl/cu121

echo "$(ts) Installing ONNX (wheel)..."
"$MICROMAMBA" run -n cb311 pip install --progress-bar on onnx==1.16.0

echo "$(ts) Installing Chatterbox package (from GitHub, no-cache, upgrade)..."
"$MICROMAMBA" run -n cb311 pip uninstall -y chatterbox-tts chatterbox || true
"$MICROMAMBA" run -n cb311 pip install \
  --no-cache-dir --upgrade \
  --progress-bar on \
  "chatterbox-tts @ git+https://github.com/devnen/chatterbox-v2.git@master"

echo "$(ts) ✅ Installation complete!"

# %%
# %%capture
# %%bash
set -e

/content/bin/micromamba run -n cb311 python - <<'PY'
import inspect, torch
import chatterbox.tts_turbo as t

print("✅ torch:", torch.__version__)
print("✅ cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("✅ gpu:", torch.cuda.get_device_name(0))

print("✅ chatterbox.tts_turbo path:", t.__file__)

src = inspect.getsource(t.ChatterboxTurboTTS.from_pretrained)
print("\n--- from_pretrained() (first ~80 lines) ---")
print("\n".join(src.splitlines()[:80]))

# Heuristic check for the common buggy pattern that forces token=True semantics
markers = [" or True", "token=True", "token = True", "use_auth_token=True"]
hits = [m for m in markers if m in src]
print("\nHeuristic auth-forcing markers found:", hits)

if hits:
    raise SystemExit(
        "\n❌ This install still appears to force HF auth.\n"
        "Re-run Cell 2 (it already uses --no-cache-dir --upgrade).\n"
    )

print("\n✅ Looks good: Turbo should download without requiring user tokens.")
PY

# %%
# %%capture
# %%bash
set -e

echo "Patching Chatterbox to handle missing watermarker..."

/content/bin/micromamba run -n cb311 python - <<'PY'
import sys
from pathlib import Path

# Find the tts_turbo.py file
import chatterbox.tts_turbo as t
turbo_file = Path(t.__file__)

print(f"Patching: {turbo_file}")

# Read the file
content = turbo_file.read_text()

# Patch 1: Fix watermarker initialization
old_init = "        self.watermarker = perth.PerthImplicitWatermarker()"
new_init = """        try:
            self.watermarker = perth.PerthImplicitWatermarker() if perth.PerthImplicitWatermarker is not None else None
        except (TypeError, AttributeError):
            print("Warning: Watermarker not available, skipping...")
            self.watermarker = None"""

# Patch 2: Fix watermark application in generate method
old_watermark = "        watermarked_wav = self.watermarker.apply_watermark(wav, sample_rate=self.sr)"
new_watermark = """        if self.watermarker is not None:
            watermarked_wav = self.watermarker.apply_watermark(wav, sample_rate=self.sr)
        else:
            watermarked_wav = wav"""

patches_applied = 0

if old_init in content:
    content = content.replace(old_init, new_init)
    print("✅ Patched watermarker initialization")
    patches_applied += 1
else:
    print("⚠️  Init pattern not found or already patched")

if old_watermark in content:
    content = content.replace(old_watermark, new_watermark)
    print("✅ Patched watermark application in generate()")
    patches_applied += 1
else:
    print("⚠️  Watermark apply pattern not found or already patched")

if patches_applied > 0:
    turbo_file.write_text(content)
    print(f"\n✅ Applied {patches_applied} patch(es) successfully")
else:
    print("\n⚠️  No patches applied - file may already be patched or structure changed")

PY

echo "✅ Patch complete!"

# %%
# @title 4. Install Server + Run With Full Live Logs (foreground)
import os, time, subprocess, socket, requests
from pathlib import Path

PORT = 8004
REPO_DIR = "/content/Chatterbox-TTS-Server"
LOG_STDOUT = "/content/chatterbox_server_stdout.log"

def sh(cmd, check=False):
    return subprocess.run(["bash", "-lc", cmd], check=check)

def port_open(host="127.0.0.1", port=PORT, timeout=0.25):
    try:
        with socket.create_connection((host, port), timeout=timeout):
            return True
    except OSError:
        return False

os.chdir("/content")

# Fresh clone
sh("rm -rf /content/Chatterbox-TTS-Server", check=False)
sh("git clone https://github.com/devnen/Chatterbox-TTS-Server.git", check=True)
os.chdir(REPO_DIR)

print("=== Quick system checks ===")
sh("nvidia-smi || true", check=False)

print("\n=== Installing server requirements (prefer repo pins if present) ===")
if Path("requirements-nvidia.txt").exists():
    sh("/content/bin/micromamba run -n cb311 pip install -U pip setuptools wheel", check=False)
    sh("/content/bin/micromamba run -n cb311 pip install -r requirements-nvidia.txt", check=False)
else:
    sh(
        "/content/bin/micromamba run -n cb311 pip install -U pip setuptools wheel && "
        "/content/bin/micromamba run -n cb311 pip install "
        "fastapi 'uvicorn[standard]' pyyaml soundfile librosa safetensors "
        "python-multipart requests jinja2 watchdog aiofiles unidecode inflect tqdm "
        "pydub audiotsm praat-parselmouth",
        check=False
    )

print("\n=== Removing old stdout log ===")
Path(LOG_STDOUT).unlink(missing_ok=True)

print("\n=== Starting server with LIVE logs ===")
print("Log file:", LOG_STDOUT)
print("To stop the server, run Cell 5.\n")

env = os.environ.copy()
env["PYTHONUNBUFFERED"] = "1"

# Put HF cache somewhere inspectable/persistent for this runtime
env["HF_HOME"] = "/content/hf_home"
env["TRANSFORMERS_CACHE"] = "/content/hf_home/transformers"
env["HF_HUB_CACHE"] = "/content/hf_home/hub"
Path(env["HF_HOME"]).mkdir(parents=True, exist_ok=True)

proc = subprocess.Popen(
    ["/content/bin/micromamba", "run", "-n", "cb311", "python", "-u", "server.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    env=env,
)

with open(LOG_STDOUT, "w", encoding="utf-8", errors="replace") as f:
    shown_link = False
    while True:
        line = proc.stdout.readline()
        if line:
            print(line, end="")
            f.write(line)
            f.flush()

        if (not shown_link) and port_open():
            shown_link = True
            print("\n=== Server port is reachable ===")
            print("Click the Colab proxy link below to open the Web UI.")
            from google.colab.output import serve_kernel_port_as_window
            serve_kernel_port_as_window(PORT)

            # Verify model load status via server endpoint
            try:
                mi = requests.get(f"http://127.0.0.1:{PORT}/api/model-info", timeout=2).json()
                print("\n/api/model-info:", mi)
            except Exception as e:
                print("\n/api/model-info query failed:", repr(e))

        if proc.poll() is not None:
            print("\n=== Server process exited with code", proc.returncode, "===")
            break
# Out:
# === Quick system checks ===
#
# === Installing server requirements (prefer repo pins if present) ===
#
# === Removing old stdout log ===
#
# === Starting server with LIVE logs ===
# Log file: /content/chatterbox_server_stdout.log
# To stop the server, run Cell 5.
#
# /root/.local/share/mamba/envs/cb311/lib/python3.11/site-packages/transformers/utils/hub.py:128: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Parselmouth library not found. Unvoiced segment removal feature will be disabled.
# 2026-02-10 11:46:32 [INFO] __main__: Starting TTS Server directly on http://0.0.0.0:8004
# 2026-02-10 11:46:32 [INFO] __main__: API documentation will be available at http://0.0.0.0:8004/docs
# 2026-02-10 11:46:32 [INFO] __main__: Web UI will be available at http://0.0.0.0:8004/
# INFO:     Started server process [4388]
# INFO:     Waiting for application startup.
# 2026-02-10 11:46:32 [INFO] server: TTS Server: Initializing application...
# 2026-02-10 11:46:32 [INFO] server: Configuration loaded. Log file at: /content/Chatterbox-TTS-Server/logs/tts_server.log
# 2026-02-10 11:46:32 [INFO] engine: CUDA requested and functional. Using CUDA.
# 2026-02-10 11:46:32 [INFO] engine: Final device selection: cuda
# 2026-02-10 11:46:32 [INFO] engine: Model selector from config: 'chatterbox-turbo'
# 2026-02-10 11:46:32 [INFO] engine: Model selector 'chatterbox-turbo' resolved to Turbo model (ChatterboxTurboTTS)
# 2026-02-10 11:46:32 [INFO] engine: Initializing ChatterboxTurboTTS on device 'cuda'...
# 2026-02-10 11:46:32 [INFO] engine: Model type: turbo
# 2026-02-10 11:46:32 [INFO] engine: Turbo model supports paralinguistic tags: ['laugh', 'chuckle', 'sigh', 'gasp', 'cough', 'clear throat', 'sniff', 'groan', 'shush']
#
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Fetching 10 files:  10%|█         | 1/10 [00:00<00:02,  4.29it/s]
# Fetching 10 files:  20%|██        | 2/10 [00:00<00:03,  2.26it/s]
# Fetching 10 files:  40%|████      | 4/10 [00:24<00:45,  7.53s/it]
# Fetching 10 files: 100%|██████████| 10/10 [00:24<00:00,  2.43s/it]
# /root/.local/share/mamba/envs/cb311/lib/python3.11/site-packages/diffusers/models/lora.py:393: FutureWarning: `LoRACompatibleLinear` is deprecated and will be removed in version 1.0.0. Use of `LoRACompatibleLinear` is deprecated. Please switch to PEFT backend by installing PEFT: `pip install peft`.
#   deprecate("LoRACompatibleLinear", "1.0.0", deprecation_message)
# 2026-02-10 11:47:18 [INFO] root: input frame rate=25
# 2026-02-10 11:47:23 [INFO] engine: Successfully loaded ChatterboxTurboTTS on cuda
# 2026-02-10 11:47:23 [INFO] engine: Model sample rate: 24000 Hz
# 2026-02-10 11:47:23 [INFO] engine: TTS Model loaded successfully on cuda. Engine sample rate: 24000 Hz.
# 2026-02-10 11:47:23 [INFO] server: TTS Model loaded successfully via engine.
# 2026-02-10 11:47:23 [INFO] server: Application startup sequence complete.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8004 (Press CTRL+C to quit)
#
# === Server port is reachable ===
# Click the Colab proxy link below to open the Web UI.
# Warning: This function may stop working due to changes in browser security.
# Try `serve_kernel_port_as_iframe` instead.
# /api/model-info: {'loaded': True, 'type': 'turbo', 'class_name': 'ChatterboxTurboTTS', 'device': 'cuda', 'sample_rate': 24000, 'supports_paralinguistic_tags': True, 'available_paralinguistic_tags': ['laugh', 'chuckle', 'sigh', 'gasp', 'cough', 'clear throat', 'sniff', 'groan', 'shush'], 'turbo_available_in_package': True}
# 2026-02-10 11:47:24 [INFO] server: Attempting to open web browser to: http://localhost:8004/
# 2026-02-10 11:51:29 [INFO] server: Request received for main UI page ('/').
# 2026-02-10 11:51:31 [INFO] server: Request received for /api/ui/initial-data.
# 2026-02-10 11:51:31 [INFO] utils: Found 28 predefined voices in /content/Chatterbox-TTS-Server/voices
# 2026-02-10 11:51:52 [INFO] server: Request received for /save_settings.
# 2026-02-10 11:51:52 [INFO] config: TTS processing device resolved to: cuda
# 2026-02-10 11:51:52 [INFO] config: Configuration successfully saved to config.yaml
# 2026-02-10 11:51:52 [INFO] config: Configuration updated, saved, and re-resolved successfully.
# 2026-02-10 11:52:17 [INFO] server: Received /tts request: mode='predefined', format='wav'
# 2026-02-10 11:52:17 [INFO] server: Using predefined voice: Alice.wav
# 2026-02-10 11:52:17 [INFO] server: Splitting text into chunks of size ~240.
# 2026-02-10 11:52:17 [INFO] utils: Text chunking complete. Generated 6 chunk(s).
# 2026-02-10 11:52:17 [INFO] server: Synthesizing chunk 1/6...
# 2026-02-10 11:52:17 [INFO] engine: Applying user-provided seed for generation: 3000
# 2026-02-10 11:52:17 [INFO] engine: Global seed set to: 3000
# 2026-02-10 11:52:40 [WARNING] chatterbox.tts_turbo: CFG, min_p and exaggeration are not supported by Turbo version and will be ignored.
#
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   1%|          | 6/1000 [00:00<00:17, 56.35it/s]
#   1%|▏         | 13/1000 [00:00<00:15, 64.00it/s]
#   2%|▏         | 21/1000 [00:00<00:14, 68.05it/s]
#   3%|▎         | 28/1000 [00:00<00:14, 66.25it/s]
#   4%|▎         | 36/1000 [00:00<00:13, 68.98it/s]
#   4%|▍         | 44/1000 [00:00<00:13, 69.88it/s]
#   5%|▌         | 52/1000 [00:00<00:13, 71.98it/s]
#   6%|▌         | 60/1000 [00:00<00:12, 73.21it/s]
#   7%|▋         | 68/1000 [00:00<00:12, 73.16it/s]
#   8%|▊         | 76/1000 [00:01<00:13, 67.75it/s]
#   8%|▊         | 84/1000 [00:01<00:13, 70.22it/s]
#   9%|▉         | 92/1000 [00:01<00:12, 71.63it/s]
#  10%|█         | 100/1000 [00:01<00:12, 69.70it/s]
#  11%|█         | 108/1000 [00:01<00:12, 71.12it/s]
#  12%|█▏        | 116/1000 [00:01<00:12, 71.77it/s]
#  12%|█▏        | 124/1000 [00:01<00:12, 69.79it/s]
#  13%|█▎        | 132/1000 [00:01<00:12, 70.87it/s]
#  14%|█▍        | 140/1000 [00:02<00:12, 67.88it/s]
#  15%|█▍        | 148/1000 [00:02<00:12, 69.73it/s]
#  16%|█▌        | 156/1000 [00:02<00:12, 69.54it/s]
#  16%|█▋        | 164/1000 [00:02<00:11, 70.35it/s]
#  17%|█▋        | 172/1000 [00:02<00:12, 67.65it/s]
#  18%|█▊        | 179/1000 [00:02<00:12, 67.88it/s]
#  19%|█▊        | 186/1000 [00:02<00:12, 67.41it/s]
#  19%|█▉        | 193/1000 [00:02<00:12, 67.18it/s]
#  18%|█▊        | 180/1000 [00:03<00:12, 64.85it/s]
#  19%|█▉        | 188/1000 [00:03<00:12, 66.57it/s]
#  20%|█▉        | 195/1000 [00:03<00:12, 64.73it/s]
#  20%|██        | 203/1000 [00:03<00:11, 66.66it/s]
#  21%|██        | 211/1000 [00:03<00:11, 68.41it/s]
#  22%|██▏       | 219/1000 [00:03<00:11, 69.96it/s]
#  23%|██▎       | 227/1000 [00:03<00:11, 69.56it/s]
#  24%|██▎       | 235/1000 [00:04<00:10, 70.80it/s]
#  24%|██▍       | 243/1000 [00:04<00:10, 71.10it/s]
#  25%|██▌       | 251/1000 [00:04<00:10, 72.13it/s]
#  26%|██▌       | 259/1000 [00:04<00:10, 71.63it/s]
#  27%|██▋       | 267/1000 [00:04<00:10, 68.10it/s]
#  28%|██▊       | 275/1000 [00:04<00:10, 68.84it/s]
#  28%|██▊       | 283/1000 [00:04<00:10, 70.14it/s]
#  29%|██▉       | 291/1000 [00:04<00:10, 69.08it/s]
#  30%|██▉       | 299/1000 [00:05<00:10, 70.07it/s]
#  31%|███       | 307/1000 [00:05<00:09, 70.31it/s]
#  32%|███▏      | 315/1000 [00:05<00:09, 70.36it/s]
#  32%|███▏      | 323/1000 [00:05<00:09, 70.36it/s]
#  33%|███▎      | 331/1000 [00:05<00:09, 71.29it/s]
#  34%|███▍      | 339/1000 [00:05<00:09, 67.87it/s]
#  34%|███▍      | 344/1000 [00:05<00:10, 60.58it/s]
# S3 Token -> Mel Inference...
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:00<00:00,  7.78it/s]
# 100%|██████████| 2/2 [00:00<00:00,  8.29it/s]
# 100%|██████████| 2/2 [00:00<00:00,  8.20it/s]
# 2026-02-10 11:53:20 [INFO] server: Smart stitching applied: 6 chunks, 20ms crossfades, 200ms pauses
# 2026-02-10 11:53:20 [INFO] utils: Encoded 4583084 bytes to 'wav' at 24000Hz in 0.008 seconds.
# 2026-02-10 11:53:20 [INFO] server: Successfully generated audio: tts_output_20260210_115320.wav, 4583084 bytes, type audio/wav.
# 2026-02-10 11:53:20 [INFO] server: Request received for /save_settings.
# 2026-02-10 11:53:20 [INFO] config: TTS processing device resolved to: cuda
# 2026-02-10 11:53:20 [INFO] config: Configuration successfully saved to config.yaml
# 2026-02-10 11:53:20 [INFO] config: Configuration updated, saved, and re-resolved successfully.
# 2026-02-10 13:07:42 [INFO] server: Request received for main UI page ('/').
# 2026-02-10 13:07:43 [INFO] server: Request received for /api/ui/initial-data.
# 2026-02-10 13:07:43 [INFO] utils: Found 28 predefined voices in /content/Chatterbox-TTS-Server/voices
# 2026-02-10 13:09:49 [INFO] server: Received /tts request: mode='predefined', format='wav'
# 2026-02-10 13:09:49 [INFO] server: Using predefined voice: Alice.wav
# 2026-02-10 13:09:49 [INFO] server: Splitting text into chunks of size ~240.
# 2026-02-10 13:09:49 [INFO] utils: Text chunking complete. Generated 6 chunk(s).
# 2026-02-10 13:09:49 [INFO] server: Synthesizing chunk 1/6...
# 2026-02-10 13:09:49 [INFO] engine: Applying user-provided seed for generation: 3000
# 2026-02-10 13:09:49 [INFO] engine: Global seed set to: 3000
# 2026-02-10 13:09:49 [WARNING] chatterbox.tts_turbo: CFG, min_p and exaggeration are not supported by Turbo version and will be ignored.
#
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 4/1000 [00:00<00:27, 35.71it/s]
#   1%|          | 11/1000 [00:00<00:18, 52.61it/s]
#   2%|▏         | 18/1000 [00:00<00:16,
/s]
# S3 Token -> Mel Inference...
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:00<00:00,  7.36it/s]
# 100%|██████████| 2/2 [00:00<00:00,  8.02it/s]
# 100%|██████████| 2/2 [00:00<00:00,  7.91it/s]
# 2026-02-10 13:10:29 [INFO] server: Smart stitching applied: 6 chunks, 20ms crossfades, 200ms pauses
# 2026-02-10 13:10:29 [INFO] utils: Encoded 4583084 bytes to 'wav' at 24000Hz in 0.005 seconds.
# 2026-02-10 13:10:29 [INFO] server: Successfully generated audio: tts_output_20260210_131029.wav, 4583084 bytes, type audio/wav.
# 2026-02-10 13:11:14 [INFO] server: Request received for /save_settings.
# 2026-02-10 13:11:14 [INFO] config: TTS processing device resolved to: cuda
# 2026-02-10 13:11:14 [INFO] config: Configuration successfully saved to config.yaml
# 2026-02-10 13:11:14 [INFO] config: Configuration updated, saved, and re-resolved successfully.
# 2026-02-10 13:11:18 [INFO] server: Request received for /save_settings.
# 2026-02-10 13:11:18 [INFO] config: TTS processing device resolved to: cuda
# 2026-02-10 13:11:18 [INFO] config: Configuration successfully saved to config.yaml
# 2026-02-10 13:11:18 [INFO] config: Configuration updated, saved, and re-resolved successfully.
# 2026-02-10 13:11:23 [INFO] server: Received /tts request: mode='predefined', format='wav'
# 2026-02-10 13:11:23 [INFO] server: Using predefined voice: Alexander.wav
# 2026-02-10 13:11:23 [INFO] server: Splitting text into chunks of size ~240.
# 2026-02-10 13:11:23 [INFO] utils: Text chunking complete. Generated 5 chunk(s).
# 2026-02-10 13:11:23 [INFO] server: Synthesizing chunk 1/5...
# 2026-02-10 13:11:23 [INFO] engine: Applying user-provided seed for generation: 4096
# 2026-02-10 13:11:23 [INFO] engine: Global seed set to: 4096
# 2026-02-10 13:11:23 [WARNING] root: Reference mel length is not equal to 2 * reference token length.
#
# 2026-02-10 13:11:23 [WARNING] chatterbox.tts_turbo: CFG, min_p and exaggeration are not supported by Turbo version and will be ignored.
#
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 4/1000 [00:00<00:27, 36.46it/s]
#   1%|          | 12/1000 [00:00<00:17, 55.85it/s]
#   2%|▏         | 20/1000 [00:00<00:15, 63.38it/s]
#   3%|▎         | 27/1000 [00:00<00:15, 62.55it/s]
#   4%|▎         | 35/1000 [00:00<00:14, 66.18it/s]
#   4%|▍         | 43/1000 [00:00<00:13, 69.28it/s]
#   5%|▌         | 51/1000 [00:00<00:13, 71.73it/s]
#   6%|▌         | 59/1000 [00:00<00:12, 72.82it/s]
#   7%|▋         | 67/1000 [00:00<00:12, 73.20it/s]
#   8%|▊         | 75/1000 [00:01<00:12, 72.76it/s]
#   8%|▊         | 83/1000 [00:01<00:12, 74.09it/s]
#   9%|▉         | 91/1000 [00:01<00:12, 74.21it/s]
#  10%|▉         | 99/1000 [00:01<00:12, 71.81it/s]
#  11%|█         | 107/1000 [00:01<00:12, 72.26it/s]
#  12%|█▏        | 115/1000 [00:01<00:12, 72.66it/s]
#  12%|█▏        | 123/1000 [00:01<00:11, 73.32it/s]
#  13%|█▎        | 131/1000 [00:01<00:11, 74.10it/s]
#  14%|█▍        | 139/1000 [00:01<00:11, 72.90it/s]
#  15%|█▍        | 147/1000 [00:02<00:11, 72.73it/s]
#  15%|█▌        | 151/1000 [00:02<00:12, 70.25it/s]
# S3 Token -> Mel Inference...
#
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 13.98it/s]
# 100%|██████████| 2/2 [00:00<00:00, 13.96it/s]
# 2026-02-10 13:11:25 [INFO] server: Synthesizing chunk 2/5...
# 2026-02-10 13:11:25 [INFO] engine: Applying user-provided seed for generation: 4096
# 2026-02-10 13:11:25 [INFO] engine: Global seed set to: 4096
# 2026-02-10 13:11:25 [WARNING] root: Reference mel length is not equal to 2 * reference token length.
#
# 2026-02-10 13:11:25 [WARNING] chatterbox.tts_turbo: CFG, min_p and exaggeration are not supported by Turbo version and will be ignored.
#
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 5/1000 [00:00<00:20, 47.38it/s]
#   1%|▏         | 13/1000 [00:00<00:15, 64.89it/s]
#   2%|▏         | 21/1000 [00:00<00:14, 69.76it/s]
#   3%|▎         | 29/1000 [00:00<00:13, 70.51it/s]
#   4%|▎         | 37/1000 [00:00<00:13, 72.17it/s]
#   4%|▍         | 45/1000 [00:00<00:12, 74.00it/s]
#   5%|▌         | 53/1000 [00:00<00:12, 74.84it/s]
#   6%|▌         | 61/1000 [00:00<00:12, 75.38it/s]
#   7%|▋         | 69/1000 [00:00<00:13, 71.54it/s]
#   8%|▊         | 77/1000 [00:01<00:12, 72.77it/s]
#   8%|▊         | 85/1000 [00:01<00:12, 73.39it/s]
#   9%|▉         | 93/1000 [00:01<00:12, 74.40it/s]
#  10%|█         | 101/1000 [00:01<00:12, 74.68it/s]
#  11%|█         | 109/1000 [00:01<00:12, 72.86it/s]
#  12%|█▏        | 117/1000 [00:01<00:12, 73.38it/s]
#  12%|█▎        | 125/1000 [00:01<00:12, 69.80it/s]
#  13%|█▎        | 133/1000 [00:01<00:12, 67.39it/s]
#  14%|█▍        | 140/1000 [00:01<00:13, 65.51it/s]
#  15%|█▍        | 147/1000 [00:02<00:12, 66.33it/s]
#  16%|█▌        | 155/1000 [00:02<00:12, 68.19it/s]
#  16%|█▌        | 162/1000 [00:02<00:12, 68.52it/s]
#  17%|█▋        | 170/1000 [00:02<00:12, 68.29it/s]
#  18%|█▊        | 177/1000 [00:02<00:12, 68.43it/s]
#  18%|█▊        | 178/1000 [00:02<00:11, 69.90it/s]
# S3 Token -> Mel Inference...
#
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 13.29it/s]
# 100%|██████████| 2/2 [00:00<00:00, 13.27it/s]
# 2026-02-10 13:11:28 [INFO] server: Synthesizing chunk 3/5...
# 2026-02-10 13:11:28 [INFO] engine: Applying user-provided seed for generation: 4096
# 2026-02-10 13:11:28 [INFO] engine: Global seed set to: 4096
# 2026-02-10 13:11:28 [WARNING] root: Reference mel length is not equal to 2 * reference token length.
#
# 2026-02-10 13:11:28 [WARNING] chatterbox.tts_turbo: CFG, min_p and exaggeration are not supported by Turbo version and will be ignored.
#
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   1%|          | 6/1000 [00:00<00:18, 53.69it/s]
#   1%|▏         | 14/1000 [00:00<00:14, 66.24it/s]
#   2%|▏         | 22/1000 [00:00<00:13, 71.12it/s]
#   3%|▎         | 30/1000 [00:00<00:13, 71.87it/s]
#   4%|▍         | 38/1000 [00:00<00:13, 72.08it/s]
#   5%|▍         | 46/1000 [00:00<00:12, 73.69it/s]
#   5%|▌         | 54/1000 [00:00<00:12, 74.36it/s]
#   6%|▌         | 62/1000 [00:00<00:12, 74.84it/s]
#  17%|█▋        | 172/1000 [00:02<00:16, 49.15it/s]
#  18%|█▊        | 177/1000 [00:03<00:16, 48.41it/s]
#  18%|█▊        | 182/1000 [00:03<00:17, 46.15it/s]
#  19%|█▊        | 187/1000 [00:03<00:17, 46.89it/s]
#  20%|█▉        | 195/1000 [00:03<00:14, 54.31it/s]
#  20%|██        | 203/1000 [00:03<00:13, 60.29it/s]
#  21%|██        | 210/1000 [00:03<00:12, 62.72it/s]
#  22%|██▏       | 218/1000 [00:03<00:11, 66.43it/s]
#  23%|██▎       | 226/1000 [00:03<00:11, 68.26it/s]
#  23%|██▎       | 234/1000 [00:03<00:10, 70.29it/s]
#  24%|██▍       | 242/1000 [00:04<00:10, 71.07it/s]
#  25%|██▍       | 247/1000 [00:04<00:12, 59.35it/s]
# S3 Token -> Mel Inference...
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:00<00:00,  8.93it/s]
# 100%|██████████| 2/2 [00:00<00:00,  9.98it/s]
# 2026-02-10 13:11:36 [INFO] server: Synthesizing chunk 5/5...
# 2026-02-10 13:11:36 [INFO] engine: Applying user-provided seed for generation: 4096
# 2026-02-10 13:11:36 [INFO] engine: Global seed set to: 4096
# 2026-02-10 13:11:36 [WARNING] root: Reference mel length is not equal to 2 * reference token length.
#
# 2026-02-10 13:11:36 [WARNING] chatterbox.tts_turbo: CFG, min_p and exaggeration are not supported by Turbo version and will be ignored.
#
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 5/1000 [00:00<00:21, 46.04it/s]
#   1%|▏         | 13/1000 [00:00<00:15, 62.42it/s]
#   2%|▏         | 21/1000 [00:00<00:14, 67.87it/s]
#   3%|▎         | 29/1000 [00:00<00:13, 71.04it/s]
#   4%|▎         | 37/1000 [00:00<00:13, 72.42it/s]
#   4%|▍         | 45/1000 [00:00<00:13, 70.32it/s]
#   5%|▌         | 53/1000 [00:00<00:13, 68.81it/s]
#   6%|▌         | 61/1000 [00:00<00:13, 71.20it/s]
#   7%|▋         | 69/1000 [00:00<00:12, 72.16it/s]
#   8%|▊         | 77/1000 [00:01<00:12, 73.30it/s]
#   8%|▊         | 85/1000 [00:01<00:12, 72.29it/s]
#   9%|▉         | 93/1000 [00:01<00:12, 72.20it/s]
#  10%|█         | 101/1000 [00:01<00:12, 70.68it/s]
#  11%|█         | 109/1000 [00:01<00:12, 70.31it/s]
#  11%|█▏        | 113/1000 [00:01<00:12, 69.68it/s]
# S3 Token -> Mel Inference...
#
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00, 16.54it/s]
# 100%|██████████| 2/2 [00:00<00:00, 16.51it/s]
# 2026-02-10 13:11:38 [INFO] server: Smart stitching applied: 5 chunks, 20ms crossfades, 200ms pauses
# 2026-02-10 13:11:38 [INFO] utils: Encoded 1775084 bytes to 'wav' at 24000Hz in 0.004 seconds.
# 2026-02-10 13:11:38 [INFO] server: Successfully generated audio: tts_output_20260210_131138.wav, 1775084 bytes, type audio/wav.
# 2026-02-10 13:12:18 [INFO] server: Request received for /save_settings.
# 2026-02-10 13:12:18 [INFO] config: TTS processing device resolved to: cuda
# 2026-02-10 13:12:18 [INFO] config: Configuration successfully saved to config.yaml
# 2026-02-10 13:12:18 [INFO] config: Configuration updated, saved, and re-resolved successfully.
